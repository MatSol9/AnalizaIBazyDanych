# %% [markdown]
# # Mateusz Sołtys
# ## Zadanie 1

# %%
import matplotlib.pyplot as plt
import numpy as np
f = lambda x : x**2 + 5
plt.plot(np.linspace(-1, 1), [f(x) for x in np.linspace(-1, 1) ])
plt.xlabel("x")
plt.ylabel("y")
plt.legend(["y = x**2 + 5"])
plt.title("plot 1")
plt.show()
plt.plot(np.linspace(-6, 6), [f(x) for x in np.linspace(-6, 6) ])
plt.xlabel("x")
plt.ylabel("y")
plt.legend(["y = x**2 + 5"])
plt.title("plot 2")
plt.show()
plt.plot(np.linspace(0, 5), [f(x) for x in np.linspace(0, 5) ])
plt.xlabel("x")
plt.ylabel("y")
plt.legend(["y = x**2 + 5"])
plt.title("plot 3")
plt.show()

# %% [markdown]
# ## Zadanie 2

# %%
import pandas as pd
d = {'name': ["Jan", "Krzysztof", "Agata", "Kazimierz", "Andrea"], 'surname': ["Paweł", "Kowalski", "Nowak", "Duda", "Lepper"], 'age': [2, 1, 37, 15, 4], 'sex': ["m", "m", "m", "m", "w"]}
df = pd.DataFrame(data=d)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   surname  5 non-null      object
#  2   age      5 non-null      int64
#  3   sex      5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 288.0+ bytes

# %%
df.describe()
# Out:
#              age
# count   5.000000
# mean   11.800000
# std    15.155857
# min     1.000000
# 25%     2.000000
# 50%     4.000000
# 75%    15.000000
# max    37.000000

# %%
df.head(3)
# Out:
#         name   surname  age sex
# 0        Jan     Paweł    2   m
# 1  Krzysztof  Kowalski    1   m
# 2      Agata     Nowak   37   m
